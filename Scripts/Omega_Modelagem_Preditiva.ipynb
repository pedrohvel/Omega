# %%
#pip install pycaret
#pip install polars

# %%
import polars as pl

df = pl.read_feather("C:/Users/Pedro/Documents/GitHub/Omega/Pentaho/DATAWAREHOUSE_Target.feather")
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df
# Out:
#                    Timestamp  Company_Name Industry_Type  Revenue  Expenses  \
# 0        2024-02-10 19:34:13  Allen-Vasque       Energia   786575    410534
# 1        2024-02-09 19:34:13  Allen-Vasque       Energia   593903    673737
# 2        2024-02-08 19:34:13  Allen-Vasque       Energia   641133    371929
# 3        2024-02-07 19:34:13  Allen-Vasque       Energia   632057    670038
# 4        2024-02-06 19:34:13  Allen-Vasque       Energia   646939    487158
# ...                      ...           ...           ...      ...       ...
# 5706242  2017-07-18 19:34:30  Garcia Group        Logíst   717738    668817
# 5706243  2017-07-17 19:34:30  Garcia Group        Logíst   502784    545066
# 5706244  2017-07-16 19:34:30  Garcia Group        Logíst   886547    314152
# 5706245  2017-07-15 19:34:30  Garcia Group        Logíst   712000    376203
# 5706246  2017-07-14 19:34:30  Garcia Group        Logíst   568508    452016
#
# ...

# %%
from pycaret.classification import *

# Carregar o DataFrame com a coluna alvo
df = pd.read_feather("C:/Users/Pedro/Documents/GitHub/Omega/Pentaho/DATAWAREHOUSE_Target.feather")

# Inicializar o ambiente PyCaret
exp1 = setup(df, target='Target', html=False, silent=True)

# Comparar todos os modelos disponíveis
best_model = compare_models()

# Avaliar o melhor modelo
evaluate_model(best_model)

# Salvar o melhor modelo treinado
save_model(best_model, model_name="Best_Model", model_only=True, verbose=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from pycaret.classification import *
#       3 # Carregar o DataFrame com a coluna alvo
#       4 df = pd.read_feather("C:/Users/Pedro/Documents/GitHub/Omega/Pentaho/DATAWAREHOUSE_Target.feather")
#
# File c:\Users\Pedro\Projetos\Omega\.conda\Lib\site-packages\pycaret\classification\__init__.py:1
# ----> 1 from pycaret.classification.functional import (
#       2     add_metric,
#       3     automl,
#       4     blend_models,
#       5     calibrate_model,
#       6     check_drift,
#       7     check_fairness,
#       8     compare_models,
#       9     convert_model,
#      10     create_api,
#      11     create_app,
#      12     create_docker,
#      13     create_model,
#      14     dashboard,
#      15     deploy_model,
#      16     ensemble_model,
#      17     evaluate_model,
# ...
